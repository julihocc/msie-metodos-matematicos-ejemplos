# %% [markdown]
# ![{56AA4382-8DF4-4167-AE5F-AF97244A33B2}.png](attachment:{56AA4382-8DF4-4167-AE5F-AF97244A33B2}.png)

# %%
t = var('t')

x1 = 2+sin(t)
x2 = -t+cos(t)

# %%
x1.diff(t) - (x2+t)
# Out:
# 0

# %%
x2.diff(t) - (-x1+1)
# Out:
# 0

# %%
x = matrix([x1, x2]).transpose()
x
# Out:
# [ sin(t) + 2]
# [-t + cos(t)]

# %%
A = matrix([[0, 1], [-1, 0]])
A
# Out:
# [ 0  1]
# [-1  0]

# %%
b = matrix([t, 1]).transpose()
b
# Out:
# [t]
# [1]

# %%
diff(x, t) - (A*x + b)
# Out:
# [0]
# [0]
