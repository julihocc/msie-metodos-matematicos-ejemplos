# %% [markdown]
# ### Starting from Scratch

# %% [markdown]
# We define a graph as a pair $(V, E)$, where $V$ represents a set of vertices and $E$ a set of edges, or unordered pairs of vertices. The graph shown in **Figure 16.1** is defined by the set of vertices $\{0, 1, 2, 5, 9, \text{'Madrid'}, \text{'Edinburgh'}\}$ and has edges
# $(1, 2)$, $(1, 5)$, $(1, 9)$, $(2, 5)$, $(2, 9)$ as well as $(\text{'Madrid'}, \text{'Edinburgh'})$.

# %% [markdown]
# ```mermaid
# graph LR
#     0
#     1
#     2
#     5
#     9
#     Madrid["'Madrid'"]
#     Edinburgh["'Edinburgh'"]
#     1 --- 2
#     1 --- 5
#     1 --- 9
#     2 --- 5
#     2 --- 9
#     Madrid --- Edinburgh
# ```

# %%
g = Graph()

# %%
g.order(), g.size()
# Out:
# (0, 0)

# %%
g.add_vertex(0)

# %%
g.order(), g.size()
# Out:
# (1, 0)

# %% [markdown]
# ### Available Constructors

# %%
# https://en.wikipedia.org/wiki/Petersen_graph
P = graphs.PetersenGraph()
P.show()
# Out:
# Graphics object consisting of 26 graphics primitives

# %%
# https://en.wikipedia.org/wiki/Chv%C3%A1tal_graph
C = graphs.ChvatalGraph()
C.show()
# Out:
# Graphics object consisting of 37 graphics primitives

# %%
# https://en.wikipedia.org/wiki/Planar_graph
P.is_planar()
# Out:
# False

# %%
# https://en.wikipedia.org/wiki/Complete_graph
Q = graphs.CompleteGraph(5)
Q.show()
# Out:
# Graphics object consisting of 16 graphics primitives

# %%
P.minor(Q)
# Out:
# {0: [1, 6], 1: [0, 5], 2: [2, 7], 3: [4, 9], 4: [3, 8]}
